# %% [markdown]
# # **PRAKTIKUM 1 - Exploratory Data Analysis (EDA)**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Langkah 1 - Memuat Data**

# %%
df = pd.read_csv('Titanic-Dataset.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(100)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                            Allen, Mr. William Henry    male  35.0      0
# ..                                                ...     ...   ...    ...
# ...

# %% [markdown]
# ## **Langkah 2 -  Inspeksi Data**

# %% [markdown]
# ### **Pengecekan Dimensi**

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# df.shape digunakan untuk mengetahui jumlah baris dan kolom pada sebuah DataFrame. Hasilnya berupa tuple (jumlah_baris, jumlah_kolom), sehingga memudahkan kita melihat ukuran data yang sedang dianalisis.

# %% [markdown]
# ### **Pengecekan Tipe Data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# df.info() digunakan untuk menampilkan informasi ringkas tentang DataFrame, seperti jumlah baris, nama dan tipe data kolom, serta jumlah data yang tidak kosong di setiap kolom. Ini membantu memahami struktur dan kualitas data secara cepat.

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# df.isnull().sum() digunakan untuk menghitung jumlah data yang hilang (missing value) di setiap kolom pada DataFrame. Hasilnya membantu mengetahui kolom mana saja yang memiliki nilai kosong dan seberapa banyak.

# %% [markdown]
# ### **Ringkasan Nilai Statistik**

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# df.describe() digunakan untuk menampilkan ringkasan statistik dari kolom-kolom numerik pada DataFrame, seperti nilai rata-rata, standar deviasi, minimum, maksimum, dan kuartil. Ini membantu memahami distribusi dan karakteristik data secara cepat.

# %% [markdown]
# ## **Langkah 3 - Inspeksi Visual**

# %% [markdown]
# ### **Inspeksi Distribusi Data**

# %%
num_cols = ['Age','Fare']
for col in num_cols:
    plt.figure()
    plt.hist(df[col], bins=30)
    plt.title(f'Distribusi {col}')
    plt.xlabel(col); plt.ylabel('Frekuensi')
    plt.show()

# %% [markdown]
# Pada cell 20 membuat scatterplot antara kolom Age dan Fare dari DataFrame. Scatterplot ini digunakan untuk melihat hubungan atau pola distribusi antara usia penumpang dan harga tiket yang dibayar. Setiap titik pada grafik mewakili satu penumpang.

# %% [markdown]
# ### **Inspeksi Outlier**

# %%
plt.figure()
plt.boxplot(df['Fare'].dropna(), vert=True)
plt.title('Boxplot Fare')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# Percobaan diatas membuat boxplot untuk kolom Fare pada DataFrame. Boxplot digunakan untuk menampilkan distribusi data, mendeteksi outlier, serta melihat nilai minimum, maksimum, median, dan kuartil dari harga tiket (Fare)

# %% [markdown]
# ### **Inspeksi Komposisi Variabel Kualitatif**

# %%
cat_cols = ['Survived','Pclass','Sex','Embarked']

fig, axes = plt.subplots(2, 2, figsize=(10, 8))
axes = axes.flatten()

for i, col in enumerate(cat_cols):
    df[col].value_counts(dropna=False).plot(kind='bar', ax=axes[i])
    axes[i].set_title(f'Distribusi {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Jumlah')

plt.tight_layout()
plt.show()

# %% [markdown]
# Pada percobaan diatas membuat diagram batang (bar chart) untuk setiap variabel kategorikal (Survived, Pclass, Sex, Embarked). Diagram ini menampilkan jumlah data pada setiap kategori, sehingga memudahkan analisis komposisi dan distribusi data pada variabel-variabel tersebut.

# %% [markdown]
# ### **Inspeksi Korelasi**

# %% [markdown]
# #### **HeatMap**

# %%
import seaborn as sns # Import seaborn for enhanced visualization

num_only = df.select_dtypes(include=[np.number])
corr = num_only.corr(numeric_only=True)

plt.figure(figsize=(8, 6)) # Increased figure size for better readability
sns.heatmap(corr, cmap='coolwarm', vmin=-1, vmax=1, annot=True, fmt=".2f") # Use seaborn.heatmap with annotation
plt.title('Heatmap Korelasi (numerik)')
plt.tight_layout()
plt.show()

# %% [markdown]
# nilai korelasi variabel lain terhadap variabel 'Survived'

# %%
corr['Survived'].sort_values(ascending=False)
# Out:
# Survived       1.000000
# Fare           0.257307
# Parch          0.081629
# PassengerId   -0.005007
# SibSp         -0.035322
# Age           -0.077221
# Pclass        -0.338481
# Name: Survived, dtype: float64

# %% [markdown]
# #### **Scatterplot**

# %%
plt.figure()
surv_map = {0:'No', 1:'Yes'}
plt.scatter(df['Age'], df['Fare'], alpha=0.7)
plt.xlabel('Age'); plt.ylabel('Fare')
plt.title('Scatter Age vs Fare')
plt.show()
